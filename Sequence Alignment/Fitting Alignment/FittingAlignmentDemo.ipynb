# %%
import Bio

# %%
from FittingAlignment import fittingAlignment
delta = {('A', 'A'): 1, ('A', 'C'): -1, ('A', 'G'): -1, ('A', 'T'): -1,
         ('C', 'C'): 1, ('C', 'G'): -1, ('C', 'T'): -1,
         ('G', 'G'): 1, ('G', 'T'): -1,
         ('T', 'T'): 1}
v = "..."
w = "..."

maxScore, n, v, w = fittingAlignment(v, w, delta, -1)
print("Max Score: " + str(maxScore))
print("Number of Optimal Alignments: " + str(n))
print("An Optimal Alignment: ")
print(v)
print(w)
